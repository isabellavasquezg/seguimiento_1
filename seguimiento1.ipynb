# %%
# Clases
class Microorganismos():
    def __init__(self): 
        self.___ident = 0
        self.___ubicacion=[] #Cree una lista donde puede ir la fila y la columna. Si te gusta, podemos borrar esos self
        #O si los prefieres separados, los dejamos. Solo es como una opción
        self.__medio = " "
        self.__peligro = " "

    def asignarIdent(self,i): 
        self.__ident = i 
    def asignarUbicacion(self, f, c): #Aquí la puse para asignar la ubicación
        self.__ubicacion=[f,c]
    def asignarFila  (self,f): 
        self.__fila = f 
    def asignarColumna(self,c):
        self.__columna = c
    def asignarMedio(self,m): 
        self.__medio = m
    def asignarPeligro (self,p): 
        self.__peligro = p 

    def verIdent(self): 
        return self.__ident
    def verFila(self): 
        return self.__fila 
    def verUbicacion(self):
        return self.__ubicacion
    def verColumna(self):
        return self.__columna
    def verMedio(self):
        return self.__medio
    def verPeligro (self): 
        return  self.__peligro
    def verUbicacion(self):
        return self.__ubicacion

    
class Bacterias (Microorganismos): 
    def __init__(self): 
        Microorganismos.__init__(self)
        self.__tipogram = " "
        self.__forma = " "
        
    def asignarTipoGram(self, gram):
        self.__tipogram = gram
    def asignarForma(self, f):
        self.__forma = f
    
    def verTipoGram(self):
        return self.__tipogram
    def verForma(self):
        return self.__forma
    
    

class Virus(Microorganismos): 
    def __init__(self): 
        Microorganismos.__init__(self)
        self.__capacidad = " "
        self.__huesped = " "

    def asignarCapacidad(self, c):
        self.__capacidad = c
    def asignarHuesped(self, h):
        self.__forma = h
    
    def verCapacidad(self):
        return self.__capacidad
    def verHuesped(self):
        return self.__hues
    
class Priones(Microorganismos): 
    def __init__(self): 
        Microorganismos.__init__(self)
        self.__especie = " "
        self.__peligrosidad = 0 

    def asignarEspecie(self, e):
        self.__especie = e
    def asignarPeligrosidad(self, p):
        self.__peligro = p
    
    def verEspecie(self):
        return self.__especie
    def verPeligrosidad(self):
        return self.__peligrosidad

class Otros (Microorganismos): 
    def __init__(self): 
        Microorganismos.__init__(self)
        self.__nombre = " "
        self.__naturaleza = " "
        self.__descripcion = " "

    def asignarNombre(self, n):
        self.__nombre = n
    def asignarNaturaleza(self, nat):
        self.__naturaleza = nat
    def asignarDescripcion(self, d):
        self.__descripcion = d
    
    def verCapacidad(self):
        return self.__nombre
    def verHuesped(self):
        return self.__naturaleza
    def verHuesped(self):
        return self.__descripcion 
        
class Sistema():
    def __init__(self):
        #Creamos el diccionario de microorganismo 
        #Clave = identificar del microorganismo valor = objeto 
        self.__Microorganismos={}

    #Creamos la fucnión que nos permite ingresar un microorganismo con la infromación 
    # que nos proporciona el usuario         
    def ingresarMicroorganismo(self,tipo, ident, objeto):
            #tipo no se está utilizando 
            self.__Microorganismos[ident]=objeto
            
   # def verMicroorganismos(self): #Esto, si no queremos hacer un ver para cada microorganismo, podemos ponerle de argumento el tipo
        #e ir cambiado la clave
       # dic=self.__Microorganismos
        #print('''MICROORGANISMOS INGRESADOS EN EL SISTEMA''')
        
       # print('BACTERIAS')
        #for bacterias in dic:
         #   if type(dic[bacterias])==Bacterias:
          #      b=dic[bacterias]

                #print(f'''

                 #   Identificador: {b.verIdent()}
                  #  Ubicación: {b.verUbicacion()[0]}, {b.verUbicacion()[1]}
                   # Medio: {b.verMedio()}
                    #Peligro: {b.verPeligro()}
                    #Tipo de Gram: {b.verTipoGram()}
                    #Forma: {b.verForma()}''')
    #Creamos una fución que nos retorne la información que guarda un microorganismo ya ingresado 
    def verMicroorganismo(self, ident): 
        return self.__Microorganismos[ident]
    
    #La fucnión eliminar me permitirá eliminar un microorganismo a través de su identificador 
    def eliminarMicroorganismo(self,ident):
        del self.__Microorganismos[ident]
    
    def verificarExiste(self,ident): #b sería 'Virus', 'Bacterias', todo eso
        if ident in self.__Microorganismos:
                return True
        else: 
            return False

    
def validarNum(datos):
    '''Función para validar las entradas en que sólo se permite el ingreso de números'''
    while True:
        try:
            d=int(input(datos))
            return d
        except ValueError:
            print('Recuerde que sólo es válido el ingreso de números. Intente nuevamente.')

def estandarizarTexto(datos): #Esta permite ingreso de sólo cadenas de texto, y las pone en mayúscula
    #Hay que preguntarle a Daniel si hay manera de no permitir tildes 
    while True:
        a=input(datos).upper()
        if a.isalpha()==False:
            print('Recuerde que en este campo se admite únicamente texto.')
        else:
            return a
        
    
def validaralfanumericos(msjd):
    while True:
        a=input(msjd).upper()
        if a.isalpha()==True:
            print('Recuerde que en este dato sólo se ingresan datos alfanuméricos, no se admiten caracteres especiales ni únicamente letras.')
        elif a.isalnum():
            return a

# %%
def main(): 
    sistema = Sistema()
    while True: 
        menu = validarNum(''' Te damos la bienvenida al sistema de almacenamiento de microorganismos
        \n Ingrese: 
        \n 1- Ingresar un microorganismo 
        \n 2- Leer la información de un microorganismo 
        \n 3- Eliminar un microorganismo \n
        \n 4- Salir del sistema''')
        if menu == 1: 
            tipo = validarNum('''Ingrese: 
            \n 1- Si el microorganismo a ingresar es una bacteria 
            \n 2- Si el microorganismo a ingresar es un Virus 
            \n 3- Si el microorganismo a ingresar es un prion 
            \n 4. Si el microorganismo a ingresar es uno diferente a los mencionado anteriormente \n ''')
            
            if tipo == 1: 
                ident = validarNum("Ingrese el identificador único del microorganismo: \n ")
                if sistema.verificarExiste(ident)== False:
                    fila =  validarNum("Ingrese el número de fila: \n") 
                    #Puse validarnum para que sólo ingresen el número de la fila o columna, y no haya tanta cabida para errores
                    columna = validarNum("Ingrese el número de columna: \n")
                    medio = estandarizarTexto("Ingrese el medio:  ") #La función estandarizarTexto lo valida y lo estandariza
                    peligro = estandarizarTexto("Ingrese si el microorganismo es o no peligroso: \n") 
                    #Para peligro deberíamos hacer una función, para que en caso de que se ingrese un valor diferente a 1.Sí o 2. No, saque error y vuelva a pedirlo
                    tipo_gram = estandarizarTexto("Ingrese si la bacteria es tipo gram positiva o gram negativa según sea el caso: ")
                    forma = estandarizarTexto("Ingrese la forma de la bacteria: \n")
                    b = Bacterias()
                    b.asignarIdent(ident)
                    f=('F'+str(fila)) #Aquí sólo convertí en str la fila que ingresó y la uní con F para darle el formato
                    c=('C'+str(columna))
                    b.asignarUbicacion(f,c) #Las agregué a las dos para que estén en la lista de ubicación
                    b.asignarMedio(medio)
                    b.asignarPeligro(peligro)
                    b.asignarTipoGram(tipo_gram)
                    b.asignarForma(forma)
                    sistema.ingresarMicroorganismo(tipo,ident,b) #Se ingresa al sistema
                    continue
                    
                else: 
                    print("El microorganismo ya se encuentra en nuestra base de datos...")
                    
            elif tipo==2:
                ident = validarNum("Ingrese el identificador único del microorganismo: \n ")
                if sistema.verificarExiste(ident)== False:
                    fila =  validarNum("Ingrese el número de fila: \n") 
                    #Puse validarnum para que sólo ingresen el número de la fila o columna, y no haya tanta cabida para errores
                    columna = validarNum("Ingrese el número de columna: \n")
                    medio = estandarizarTexto("Ingrese el medio:  \n") #La función estandarizarTexto lo valida y lo estandariza
                    peligro = estandarizarTexto("Ingrese si el microorganismo es o no peligroso: \n") 
                    #Para peligro deberíamos hacer una función, para que en caso de que se ingrese un valor diferente a 1.Sí o 2. No, saque error y vuelva a pedirlo
                    capacidad= estandarizarTexto("Ingrese la capacidad infectiva del virus: \n")
                    huesped = estandarizarTexto("Ingrese el huesped del virus: \n")
                    v = Virus()
                    v.asignarIdent(ident)
                    f=('F'+str(fila)) #Aquí sólo convertí en str la fila que ingresó y la uní con F para darle el formato
                    c=('C'+str(columna))
                    v.asignarUbicacion(f,c) #Las agregué a las dos para que estén en la lista de ubicación
                    v.asignarMedio(medio)
                    v.asignarPeligro(peligro)
                    v.asignarHuesped(huesped)
                    v.asignarCapacidad(capacidad)
                    sistema.ingresarMicroorganismo(tipo,ident,v) #Se ingresa al sistema
                    continue
               
                else: 
                    print("El microorganismo ya se encuentra en nuestra base de datos...")                                    
                
            elif tipo==3:
                ident = validarNum("Ingrese el identificador único del microorganismo: \n ")
                if sistema.verificarExiste(ident)== False:
                    fila =  validarNum("Ingrese el número de fila: \n") 
                    #Puse validarnum para que sólo ingresen el número de la fila o columna, y no haya tanta cabida para errores
                    columna = validarNum("Ingrese el número de columna: \n")
                    medio = estandarizarTexto("Ingrese el medio:  \n") #La función estandarizarTexto lo valida y lo estandariza
                    peligro = estandarizarTexto("Ingrese si el microorganismo es o no peligroso: \n") 
                    #Para peligro deberíamos hacer una función, para que en caso de que se ingrese un valor diferente a 1.Sí o 2. No, saque error y vuelva a pedirlo
                    especie= estandarizarTexto("Ingrese la especie del Prion: \n")
                    peligrosidad = estandarizarTexto("Ingrese la peligrosidad del Prion: \n")
                    p = Priones()
                    p.asignarIdent(ident)
                    f=('F'+str(fila)) #Aquí sólo convertí en str la fila que ingresó y la uní con F para darle el formato
                    c=('C'+str(columna))
                    p.asignarUbicacion(f,c) #Las agregué a las dos para que estén en la lista de ubicación
                    p.asignarMedio(medio)
                    p.asignarPeligro(peligro)
                    p.asignarEspecie(especie)
                    p.asignarPeligrosidad(peligrosidad)
                    sistema.ingresarMicroorganismo(tipo,ident,p) #Se ingresa al sistema
                    continue
               
                else: 
                    print("El microorganismo ya se encuentra en nuestra base de datos...")                                    
                
                ident = validarNum("Ingrese el identificador único del microorganismo: \n ")
                if sistema.verificarExiste(ident)== False:
                    fila =  validarNum("Ingrese el número de fila: \n") 
                    #Puse validarnum para que sólo ingresen el número de la fila o columna, y no haya tanta cabida para errores
                    columna = validarNum("Ingrese el número de columna: \n")
                    medio = estandarizarTexto("Ingrese el medio:  \n") #La función estandarizarTexto lo valida y lo estandariza
                    peligro = estandarizarTexto("Ingrese si el microorganismo es o no peligroso: \n") 
                    #Para peligro deberíamos hacer una función, para que en caso de que se ingrese un valor diferente a 1.Sí o 2. No, saque error y vuelva a pedirlo
                    nombre= estandarizarTexto("Ingrese el nombre del microorganismo: \n")
                    naturaleza= estandarizarTexto("Ingrese la naturaleza del micrroganismo: \n")
                    descripcion = estandarizarTexto("Ingrese una descripción del microorganismo: \n")
                    o = Otros()
                    o.asignarIdent(ident)
                    f=('F'+str(fila)) #Aquí sólo convertí en str la fila que ingresó y la uní con F para darle el formato
                    c=('C'+str(columna))
                    o.asignarUbicacion(f,c) #Las agregué a las dos para que estén en la lista de ubicación
                    o.asignarMedio(medio)
                    o.asignarPeligro(peligro)
                    o.asignarNombre(nombre)
                    o.asignarNaturaleza(naturaleza)
                    o.asignarDescripcion(descripcion)
                    sistema.ingresarMicroorganismo(tipo,ident,o) #Se ingresa al sistema
                    continue
               
                else: 
                    print("El microorganismo ya se encuentra en nuestra base de datos...")                                    
                
            else:
                print('Ingresó un valor por fuera del rango. Verifique e intente nuevamente')
                continue 

        elif menu==2: 
            tipo = validarNum('''Ingrese: 
            \n 1- Si el microorganismo a buscar es una bacteria 
            \n 2- Si el microorganismo a buscar es un Virus 
            \n 3- Si el microorganismo a buscar es un prion 
            \n 4. Si el microorganismo a buscarar es uno diferente a los mencionado anteriormente ''')
            
            ident=validarNum('Ingrese el identificador único del microorganismo a buscar: \n')
            if sistema.verificarExiste(ident)== True:
                
                if tipo==1:
                    a=sistema.verMicroorganismo(ident)
                    print(f'''

                    IDENTIFICADOR: {a.verIdent()}
                    UBICACIÓN: {a.verUbicacion()[0]}, {a.verUbicacion()[1]}
                    MEDIO: {a.verMedio()}
                    PELIGRO: {a.verPeligro()}
                    TIPO DE GRAM: {a.verTipoGram()}
                    FORMA: {a.verForma()}''')
                elif tipo==2:
                    a=sistema.verMicroorganismo(ident)
                    print(f'''

                    IDENTIFICADOR: {a.verIdent()}
                    UBICACIÓN: {a.verUbicacion()[0]}, {a.verUbicacion()[1]}
                    MEDIO: {a.verMedio()}
                    PELIGRO: {a.verPeligro()}
                    CAPACIDAD: {a.verCapacidad()}
                    HUESPED: {a.verHuesped()}''')
                    
                elif tipo==3:
                    a=sistema.verMicroorganismo(ident)
                    print(f'''

                    IDENTIFICADOR: {a.verIdent()}
                    UBICACIÓN: {a.verUbicacion()[0]}, {a.verUbicacion()[1]}
                    MEDIO: {a.verMedio()}
                    PELIGRO: {a.verPeligro()}
                    ESPECIE: {a.verEspecie()}
                    PELIGROSIDAD: {a.verPeligrosidad()}''')
                elif tipo==4:
                    a=sistema.verMicroorganismo(ident)
                    print(f'''

                    IDENTIFICADOR: {a.verIdent()}
                    UBICACIÓN: {a.verUbicacion()[0]}, {a.verUbicacion()[1]}
                    MEDIO: {a.verMedio()}
                    PELIGRO: {a.verPeligro()}
                    NOMBRE: {a.verNombre()}
                    NATURALEZA: {a.verNaturaleza()}
                    DESCRIPCIÓN: {a.verEspecie()}''')
            
            else:
                print('El microorganismo no se encuentra registrado en la base de datos.')

        elif menu==3:
            tipo = validarNum('''Ingrese: 
            \n 1- Si el microorganismo a eliminar es una bacteria 
            \n 2- Si el microorganismo a eliminar es un Virus 
            \n 3- Si el microorganismo a eliminar es un prion 
            \n 4. Si el microorganismo a eliminar es uno diferente a los mencionado anteriormente ''') 
            ident=validarNum('Ingrese el identificador único del microorganismo a buscar: \n')
            if sistema.verificarExiste(ident)== True:
                if tipo ==1: 
                    sistema.eliminarMicroorganismo(ident)
                elif tipo==2: 
                    sistema.eliminarMicroorganismo(ident)
                elif tipo ==3: 
                    sistema.eliminarMicroorganismo(ident) 
                elif tipo ==4: 
                    sistema.eliminarMicroorganismo(ident)
            else:
                print("El microorganismo no se encuentra registrado en la base de datos.")
        elif menu ==4:
            print("Gracias por utilizar nuestros servicios ")
            break 
        else: 
            print("Por favor ingrese un valor correcto")
