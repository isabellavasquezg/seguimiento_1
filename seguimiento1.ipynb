# %%
# Clases
class Microorganismos():
    def __init__(self): 
        self.___ident = 0
        self.___fila = " "
        self.___columna = " "
        self.__medio = " "
        self.__peligro = " "

    def asignarIdent(self,i): 
        self.__ident = i 
    def asignarFila  (self,f): 
        self.__fila = f 
    def asignarColumna(self,c):
        self.__columna = c
    def asignarMedio(self,m): 
        self.__medio = m
    def asignarPeligro (self,p): 
        self.__peligro = p 

    def verIdent(self): 
        return self.__ident
    def verFila(self): 
        return self.__fila 
    def verColumna(self):
        return self.__columna
    def verMedio(self):
        return self.__medio
    def verPeligro (self): 
        return  self.__peligro

    
class Bacterias (Microorganismos): 
    def __init__(self): 
        Microorganismos.__init__(self)
        self.__tipogram = " "
        self.__forma = " "
        
    def asignarTipoGram(self, gram):
        self.__tipogram = gram
    def asignarForma(self, f):
        self.__forma = f
    
    def verTipoGram(self):
        return self.__tipogram
    def verForma(self):
        return self.__forma
    
    

class Virus(Microorganismos): 
    def __init__(self): 
        Microorganismos.__init__(self)
        self.__capacidad = " "
        self.__huesped = " "
    
    def asignarCapacidad(self, c):
        self.__capacidad = c
    def asignarHuesped(self, h):
        self.__huesped = h
    
    def verCapacidad(self):
        return self.__capacidad
    def verHuesped(self):
        return self.__huesped
    
class Priones(Microorganismos): 
    def __init__(self): 
        Microorganismos.__init__(self)
        self.__especie = " "
        self.__peligrosidad = 0 

    def asignarEspecie(self, e):
        self.__especie = e
    def asignarPeligrosidad(self, p):
        self.__peligrosidad = p
    
    def verEspecie(self):
        return self.__especie
    def verPeligrosidad(self):
        return self.__peligrosidad
    
class Otros (Microorganismos): 
    def __init__(self): 
        Microorganismos.__init__(self)
        self.__nombre = " "
        self.__naturaleza = " "
        self.__descripcion = " "
    
    def asignarNombre (self, n):
        self.__nombre = n
    def asignarNaturaleza(self, natu):
        self.__naturaleza = natu
    def asignarDescripcion(self, d):
        self.__descripcion = d
    
    def verNombre(self):
        return self.__nombre
    def verNaturaleza(self):
        return self.__naturaleza
    def verDescripcion(self):
        return self.__descripcion


class Sistema():
    def __init__(self):
        #Crear diccionario 
        self.__Microorganismos={}
        self.__Bacterias={}
        self.__Virus={}
        self.__Priones={}
        self.__Otros={}
        
        
    def ingresarMicroorganismo(self,tipo, ident, dic):
        if tipo==1:
            self.__Bacterias[ident]=dic
        if tipo==2:
            self.__Virus[ident]=dic
        if tipo==3:
            self.__Priones[ident]=dic
        if tipo==4:
            self.__[ident]=dic
            
    def verBacterias(self):
        return self.__Bacterias
#En este parte me aparecía un error de que la función ingresarMicroorganismo no está definida. 
#Esto lo solucioné poniendo a ident y a la función ingresarMicroorganismo como argumentos
#La verdad tengo dudas en si está bien o no 
    def agregarMicroorganismo(self,tipo,ident,ingresarMicroorganismo):
        if tipo==1:
            microorganismo=ingresarMicroorganismo(self,ident,tipo)
            self.__Diccionario_microorganismos[tipo]=microorganismo
        
    
    def verificarExiste(self,b,ident):
        if ident in self.__Diccionario_microorganismos[b]:
                return True
        else: 
            return False

#Funcion eliminar #No se si falta completar
#no se si el elif nos sirva para no tener que porne if tipo ==1...
    def eliminarMicroorganismo(self, ident):
        if ident in self.__Bacterias:
            a=self.__Bacterias[ident]
            del a
            return True
        elif ident in self.__Virus: 
            a = self.__Virus[ident]
            del a
            return True  
        elif ident in self.__Priones: 
            a = self.__Otros[ident]
            del a
            return True  
        elif ident in self.__Otros: 
            a = self.__Otros[ident]
            del a
            return True          
        return False

    
def validarNum(datos):
    '''Función para validar las entradas en que sólo se permite el ingreso de números'''
    while True:
        try:
            d=int(input(datos))
            return d
        except ValueError:
            print('Recuerde que sólo es válido el ingreso de números. Intente nuevamente.')

def estandarizarDatos(datos):
    while True:
        a=input(datos).upper()
        if a.isalpha()==False:
            print('Recuerde que en este campo se admite únicamente texto.')
        else:
            return a
        
    
def validaralfanumericos(msjd):
    while True:
        a=input(msjd).upper()
        if a.isalpha()==True:
            print('Recuerde que en este dato sólo se ingresan datos alfanuméricos, no se admiten caracteres especiales ni únicamente letras.')
        elif a.isalnum():
            return a

# %%
def main(): 
    sistema = Sistema()
    while True: 
        menu = validarNum(''' Te damos la bienvenida al sistema de almacenamiento de microorganismos
        \n Ingrese: 
        \n 1- Ingresar un microorganismo
        \n 2- Leer la información de un microorganismo 
        \n 3- Eliminar un microorganismo''')
        if menu == 1: 
            tipo = validarNum('''Ingrese: 
            \n 1- Si el microorganismo a ingresar es una bacteria 
            \n 2- Si el microorganismo a ingresar es un Virus 
            \n 3- Si el microorganismo a ingresar es un prion 
            \n 2. Si el microorganismo a ingresar es uno diferente al mencionado anteriormente ''')
            if tipo == 1: 
                ident = validarNum("Ingrese el identificador único: ")
                if sistema.verificarExiste(ident)== False:
                    fila =  validaralfanumericos("Ingrese la fila: ")
                    columna = validaralfanumericos("Ingrese la columna: ")
                    medio = str(input("Ingrese el medio:  ")) #hacer una validación para solo letras (no números)
                    peligro = str(input("Ingrese si el microorganismo es o no peligros: "))
                    tipo_gram = str(input("Ingrese si la bacteria es tipo gram positiva o gram negativa según sea el caso: "))
                    forma = str(input("Ingrese la forma de la bacteria: "))
                    b = Bacterias()
                    b.asignarident(ident)
                    b.asignarFila(fila)
                    b.asignarColumna(columna)
                    b.asignarMedio(medio)
                    b.asignarPeligro(peligro)
                    b.asignarTipoGram(tipo_gram)
                    b.asignarForma(forma)
                    
                else: 
                    print("El microorganismo ya se encuentra en nuestra base de datos...")
            elif tipo==2: 
                ident = validarNum("Ingrese el identificador único: ")
                if sistema.verificarExiste(ident)== False:
                    fila =  validaralfanumericos("Ingrese la fila: ")
                    columna = validaralfanumericos("Ingrese la columna: ")
                    medio = str(input("Ingrese el medio:  ")) #hacer una validación para solo letras (no números)
                    peligro = str(input("Ingrese si el microorganismo es o no peligros: "))
                    capacidad = str(input("Ingrese la capacidad infectiva del virus "))
                    huesped = str(input("Ingrese el huesped más común de este virus "))
                    v = Virus()
                    v.asignarident(ident)
                    v.asignarFila(fila)
                    v.asignarColumna(columna)
                    v.asignarMedio(medio)
                    v.asignarPeligro(peligro)
                    v.asignarCapacidad(capacidad)
                    v.asignarHuesped(huesped)
                else:
                    print("El microorganismo ya se encuentra en nuestra base de datos...")
            elif tipo==3: 
                ident = validarNum("Ingrese el identificador único: ")
                if sistema.verificarExiste(ident)== False:
                    fila =  validaralfanumericos("Ingrese la fila: ")
                    columna = validaralfanumericos("Ingrese la columna: ")
                    medio = str(input("Ingrese el medio:  ")) #hacer una validación para solo letras (no números)
                    peligro = str(input("Ingrese si el microorganismo es o no peligros: "))
                    especie = str(input("Ingrese la especie del prion: "))
                    peligrosidad = str(input("Ingrese la peligrosidad del prion: "))
                    p = Priones()
                    p.asignarident(ident)
                    p.asignarFila(fila)
                    p.asignarColumna(columna)
                    p.asignarMedio(medio)
                    p.asignarPeligro(peligro)
                    p.asignarEspecie(especie)
                    p.asignarPeligrosidad(peligrosidad)
                else:
                    print("El microorganismo ya se encuentra en nuestra base de datos...")
            elif tipo==4: 
                ident = validarNum("Ingrese el identificador único: ")
                if sistema.verificarExiste(ident)== False:
                    fila =  validaralfanumericos("Ingrese la fila: ")
                    columna = validaralfanumericos("Ingrese la columna: ")
                    medio = str(input("Ingrese el medio:  ")) #hacer una validación para solo letras (no números)
                    peligro = str(input("Ingrese si el microorganismo es o no peligros: "))
                    nombre = str(input("Ingrese el nombre del microorganismo: "))
                    naturaleza= str(input("Ingrese la naturaleza del microorganismo: "))
                    descripcion= str(input("Ingrese una descripción del microorganismo "))
                    o = Otros()
                    o.asignarident(ident)
                    o.asignarFila(fila)
                    o.asignarColumna(columna)
                    o.asignarMedio(medio)
                    o.asignarPeligro(peligro)
                    o.asignarNombre(nombre)
                    o.asignarNaturaleza(naturaleza)
                    o.asignarDescripcion(descripcion)
                else:
                    print("El microorganismo ya se encuentra en nuestra base de datos...") 
#Me falta esta parte porque no se muy bien como llamar a las funciones para guardar la información   
        if menu==2: 
            ident = validarNum("Ingrese el identificador único: ")
            if sistema.verificarExiste(ident)== True:
                pass
