# %%
# Clases
class Microorganismos():
    def __init__(self): 
        self.___ident = 0
        self.___fila = " "
        self.___columna = " "
        self.__medio = " "
        self.__peligro = " "

    def asignarIdent(self,i): 
        self.__ident = i 
    def asignarFila  (self,f): 
        self.__fila = f 
    def asignarColumna(self,c):
        self.__columna = c
    def asignarMedio(self,m): 
        self.__medio = m
    def asignarPeligro (self,p): 
        self.__peligro = p 

    def verIdent(self): 
        return self.__ident
    def verFila(self): 
        return self.__fila 
    def verColumna(self):
        return self.__columna
    def verMedio(self):
        return self.__medio
    def verPeligro (self): 
        return  self.__peligro

    
class Bacterias (Microorganismos): 
    def __init__(self): 
        Microorganismos.__init__(self)
        self.__tipogram = " "
        self.__forma = " "
        
    def asignarTipoGram(self, gram):
        self.__tipogram = gram
    def asignarForma(self, f):
        self.__forma = f
    
    def verTipoGram(self):
        return self.__tipogram
    def verForma(self):
        return self.__forma
    
    

class Virus(Microorganismos): 
    def __init__(self): 
        Microorganismos.__init__(self)
        self.__capacidad = " "
        self.__huesped = " "
    
    def asignarCapacidad(self, c):
        self.__capacidad = c
    def asignarHuesped(self, h):
        self.__huesped = h
    
    def verCapacidad(self):
        return self.__capacidad
    def verHuesped(self):
        return self.__huesped
    
class Priones(Microorganismos): 
    def __init__(self): 
        Microorganismos.__init__(self)
        self.__especie = " "
        self.__peligrosidad = 0 

    def asignarEspecie(self, e):
        self.__especie = e
    def asignarPeligrosidad(self, p):
        self.__peligrosidad = p
    
    def verEspecie(self):
        return self.__especie
    def verPeligrosidad(self):
        return self.__peligrosidad
    
class Otros (Microorganismos): 
    def __init__(self): 
        Microorganismos.__init__(self)
        self.__nombre = " "
        self.__naturaleza = " "
        self.__descripcion = " "
    
    def asignarNombre (self, n):
        self.__nombre = n
    def asignarNaturaleza(self, natu):
        self.__naturaleza = natu
    def asignarDescripcion(self, d):
        self.__descripcion = d
    
    def verNombre(self):
        return self.__nombre
    def verNaturaleza(self):
        return self.__naturaleza
    def verDescripcion(self):
        return self.__descripcion


class Sistema():
    def __init__(self):
        #Crear diccionario 
        self.__Microorganismos={}
        self.__Bacterias={}
        self.__Virus={}
        self.__Priones={}
        self.__Otros={}
        
        
    def ingresarMicroorganismo(self,tipo, ident, dic):
        if tipo==1:
            self.__Bacterias[ident]=dic
        if tipo==2:
            self.__Virus[ident]=dic
        if tipo==3:
            self.__Priones[ident]=dic
        if tipo==4:
            self.__[ident]=dic

#Esta función es para ver si nos funciona Ojalá si :)            
    def verBacterias(self):
        return self.__Bacterias

    def agregarMicroorganismo(self,tipo,ident):
        if tipo==1:
            microorganismo=self.__Bacterias[ident]
            self.__Microorganismos["BACTERIAS"]=microorganismo
        elif tipo ==2: 
            microorganismo = self.__Virus[ident]
            self.__Microorganismos["VIRUS"]=microorganismo
        elif tipo ==3: 
            microorganismo = self.__Priones[ident]
            self.__Microorganismos["PRIONES"]=microorganismo
        elif tipo==4:
            microorganismo = self.__Otros[ident]
            self.__Microorganismos["OTROS"]=microorganismo
            
    def verificarExiste(self,b,ident):
        if ident in self.__Diccionario_microorganismos[b]:
                return True
        else: 
            return False

#Funcion eliminar #No se si falta completar
#no se si el elif nos sirva para no tener que porne if tipo ==1...
    def eliminarMicroorganismo(self,ident):
        if ident in self.__Bacterias:
            a=self.__Bacterias[ident]
            del a
            return True
        elif ident in self.__Virus: 
            a = self.__Virus[ident]
            del a
            return True  
        elif ident in self.__Priones: 
            a = self.__Otros[ident]
            del a
            return True  
        elif ident in self.__Otros: 
            a = self.__Otros[ident]
            del a
            return True          
        return False

    
def validarNum(datos):
    '''Función para validar las entradas en que sólo se permite el ingreso de números'''
    while True:
        try:
            d=int(input(datos))
            return d
        except ValueError:
            print('Recuerde que sólo es válido el ingreso de números. Intente nuevamente.')

def estandarizarDatos(datos):
    while True:
        a=input(datos).upper()
        if a.isalpha()==False:
            print('Recuerde que en este campo se admite únicamente texto.')
        else:
            return a
        
    
def validaralfanumericos(msjd):
    while True:
        a=input(msjd).upper()
        if a.isalpha()==True:
            print('Recuerde que en este dato sólo se ingresan datos alfanuméricos, no se admiten caracteres especiales ni únicamente letras.')
        elif a.isalnum():
            return a

# %%
class Microorganismos():
    def __init__(self): 
        self.___ident = 0
        self.___ubicacion=() #Cree una lista donde puede ir la fila y la columna. Si te gusta, podemos borrar esos self
        #O si los prefieres separados, los dejamos. Solo es como una opción
        self.___fila = " "
        self.___columna = " "
        self.__medio = " "
        self.__peligro = " "

    def asignarIdent(self,i): 
        self.__ident = i 
    def asignarUbicacion(self, f, c): #Aquí la puse para asignar la ubicación
        self.__ubicacion=(f,c)
    def asignarFila  (self,f): 
        self.__fila = f 
    def asignarColumna(self,c):
        self.__columna = c
    def asignarMedio(self,m): 
        self.__medio = m
    def asignarPeligro (self,p): 
        self.__peligro = p 

    def verIdent(self): 
        return self.__ident
    def verFila(self): 
        return self.__fila 
    def verUbicacion(self):
        return self.__ubicacion
    def verColumna(self):
        return self.__columna
    def verMedio(self):
        return self.__medio
    def verPeligro (self): 
        return  self.__peligro
    def verUbicacion(self):
        return self.__ubicacion

    
class Bacterias (Microorganismos): 
    def __init__(self): 
        Microorganismos.__init__(self)
        self.__tipogram = " "
        self.__forma = " "
        
    def asignarTipoGram(self, gram):
        self.__tipogram = gram
    def asignarForma(self, f):
        self.__forma = f
    
    def verTipoGram(self):
        return self.__tipogram
    def verForma(self):
        return self.__forma
    
    

class Virus(Microorganismos): 
    def __init__(self): 
        Microorganismos.__init__(self)
        self.__capacidad = " "
        self.__huesped = " "
    
class Priones(Microorganismos): 
    def __init__(self): 
        Microorganismos.__init__(self)
        self.especie = " "
        self.__peligrosidad = 0 

class Otros (Microorganismos): 
    def __init__(self): 
        Microorganismos.__init__(self)
        self.__nombre = " "
        self.__naturaleza = " "
        self.__descripcion = " "
        
        
class Sistema():
    def __init__(self):
        #Crear diccionario 
        self.__Microorganismos={'Bacterias':{},'Virus':{},'Priones':{}, 'Otros':{}}
        
        #En lugar de tener varios diccionarios mejor creé solo uno donde estén todos. Y hasta ahora funciona jajaja
        
    def ingresarMicroorganismo(self,tipo, ident, dic):
        if tipo==1:
            self.__Microorganismos['Bacterias'][ident]=dic 
        if tipo==2:
            self.__Microorganismos['Virus'][ident]=dic
        if tipo==3:
            self.__Microorganismos['Priones'][ident]=dic
        if tipo==4:
            self.__Microorganismos['Otros'][ident]=dic
            
    def verBacterias(self): #Esto, si no queremos hacer un ver para cada microorganismo, podemos ponerle de argumento el tipo
        #e ir cambiado la clave
        return self.__Microorganismos['Bacterias']
    
        #Eliminar
    
    def verificarExiste(self,b,ident): #b sería 'Virus', 'Bacterias', todo eso
        if ident in self.__Microorganismos[b]:
                return True
        else: 
            return False

    
def validarNum(datos):
    '''Función para validar las entradas en que sólo se permite el ingreso de números'''
    while True:
        try:
            d=int(input(datos))
            return d
        except ValueError:
            print('Recuerde que sólo es válido el ingreso de números. Intente nuevamente.')

def estandarizarTexto(datos): #Esta permite ingreso de sólo cadenas de texto, y las pone en mayúscula
    #Hay que preguntarle a Daniel si hay manera de no permitir tildes 
    while True:
        a=input(datos).upper()
        if a.isalpha()==False:
            print('Recuerde que en este campo se admite únicamente texto.')
        else:
            return a
        
    
def validaralfanumericos(msjd):
    while True:
        a=input(msjd).upper()
        if a.isalpha()==True:
            print('Recuerde que en este dato sólo se ingresan datos alfanuméricos, no se admiten caracteres especiales ni únicamente letras.')
        elif a.isalnum():
            return a

# %%
def main(): 
    sistema = Sistema()
    while True: 
        menu = validarNum(''' Te damos la bienvenida al sistema de almacenamiento de microorganismos
        \n Ingrese: 
        \n 1- Ingresar un microorganismo
        \n 2- Leer la información de un microorganismo 
        \n 3- Eliminar un microorganismo''')
        if menu == 1: 
            tipo = validarNum('''Ingrese: 
            \n 1- Si el microorganismo a ingresar es una bacteria 
            \n 2- Si el microorganismo a ingresar es un Virus 
            \n 3- Si el microorganismo a ingresar es un prion 
            \n 2. Si el microorganismo a ingresar es uno diferente a los mencionado anteriormente ''')
            
            if tipo == 1: 
                ident = validarNum("Ingrese el identificador único: ")
                if sistema.verificarExiste('Bacterias', ident)== False:
                    fila =  validarNum("Ingrese el número de fila: ") 
                    #Puse validarnum para que sólo ingresen el número de la fila o columna, y no haya tanta cabida para errores
                    columna = validarNum("Ingrese el número de columna: ")
                    medio = estandarizarTexto("Ingrese el medio:  ") #La función estandarizarTexto lo valida y lo estandariza
                    peligro = estandarizarTexto("Ingrese si el microorganismo es o no peligroso: ") 
                    #Para peligro deberíamos hacer una función, para que en caso de que se ingrese un valor diferente a 1.Sí o 2. No, saque error y vuelva a pedirlo
                    tipo_gram = estandarizarTexto("Ingrese si la bacteria es tipo gram positiva o gram negativa según sea el caso: ")
                    forma = estandarizarTexto("Ingrese la forma de la bacteria: ")
                    b = Bacterias()
                    b.asignarIdent(ident)
                    b.asignarFila(fila)
                    b.asignarColumna(columna)
                    f=('F'+str(fila)) #Aquí sólo convertí en str la fila que ingresó y la uní con F para darle el formato
                    c=('C'+str(columna))
                    b.asignarUbicacion(f,c) #Las agregué a las dos para que estén en la lista de ubicación
                    b.asignarMedio(medio)
                    b.asignarPeligro(peligro)
                    b.asignarTipoGram(tipo_gram)
                    b.asignarForma(forma)
                    informacion={'Fila': b.verFila(), 'Columna': b.verColumna(), 'Ubicacion': b.verUbicacion(), 
                                'Medio': b.verMedio(), 'Peligro': b.verPeligro(),
                                'Gram': b.verTipoGram(), 'Forma': b.verForma()} 
                    #Se crea el diccionario con toda la información, que será el valor de la llave "identificador"
                    
                    sistema.ingresarMicroorganismo(tipo,ident,informacion) #Se ingresa al sistema
                    print(sistema.verBacterias()) #Puse print para ver si funcionaba 
                    continue
                else: 
                    print("El microorganismo ya se encuentra en nuestra base de datos...")
                    
            elif tipo==2:
                pass
            elif tipo==3:
                pass
            elif tipo==4:
                pass
            else:
                print('Ingresó un valor por fuera del rango. Verifique e intente nuevamente')
                continue 

        elif menu==2: 
            ident = validarNum("Ingrese el identificador único: ")
            if sistema.verificarExiste(ident)== True:
                pass
        elif menu==3:
            pass
